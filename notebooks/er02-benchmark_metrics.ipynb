# %% [markdown]
# # Benchmaring metrics
#
# ## Step 0- Install packages
#
# The `pbxplore` package provides tools for analyzing and visualizing Protein Block sequences, offering advanced methods for protein structure analysis. `pooch` is a Python package that manages the download of data files and their local storage, making it easier to fetch and cache datasets needed for analysis. Both packages can be installed using pip: `pip install pbxplore pooch`.

# %%
! pip install pbxplore pooch
# Out:
# Requirement already satisfied: pbxplore in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: pooch in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (1.8.2)
# Requirement already satisfied: numpy in /home/etienne-reboul/.local/lib/python3.10/site-packages (from pbxplore) (1.26.4)
# Requirement already satisfied: MDAnalysis>=0.11 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from pbxplore) (2.8.0)
# Requirement already satisfied: matplotlib in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from pbxplore) (3.10.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from pooch) (4.3.6)
# Requirement already satisfied: packaging>=20.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from pooch) (24.2)
# Requirement already satisfied: requests>=2.19.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from pooch) (2.32.3)
# Requirement already satisfied: GridDataFormats>=0.4.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (1.0.2)
# Requirement already satisfied: mmtf-python>=1.0.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (1.1.3)
# Requirement already satisfied: joblib>=0.12 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/etienne-reboul/.local/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (1.12.0)
# Requirement already satisfied: tqdm>=4.43.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (4.67.1)
# Requirement already satisfied: threadpoolctl in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (3.5.0)
# Requirement already satisfied: fasteners in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (0.19)
# Requirement already satisfied: mda-xdrlib in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (0.2.0)
# Requirement already satisfied: waterdynamics in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (0.0.0)
# Requirement already satisfied: pathsimanalysis in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (0.0.0)
# Requirement already satisfied: mdahole2 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from MDAnalysis>=0.11->pbxplore) (0.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from matplotlib->pbxplore) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from matplotlib->pbxplore) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from matplotlib->pbxplore) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from matplotlib->pbxplore) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from matplotlib->pbxplore) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from matplotlib->pbxplore) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from matplotlib->pbxplore) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from requests>=2.19.0->pooch) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from requests>=2.19.0->pooch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from requests>=2.19.0->pooch) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from requests>=2.19.0->pooch) (2025.1.31)
# Requirement already satisfied: mrcfile in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from GridDataFormats>=0.4.0->MDAnalysis>=0.11->pbxplore) (1.5.3)
# Requirement already satisfied: msgpack>=1.0.0 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from mmtf-python>=1.0.0->MDAnalysis>=0.11->pbxplore) (1.1.0)
# Requirement already satisfied: six>=1.5 in /home/etienne-reboul/anaconda3/envs/Menger_Curvature/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pbxplore) (1.17.0)

# %%
import time
import tarfile
import pbxplore as pbx
import numpy as np
import pooch
from menger.data import files
from menger.analysis.mengercurvature import MengerCurvature
import MDAnalysis as mda
from MDAnalysis.analysis import rms, align

# %% [markdown]
# ## Step 1- Data retrieval
#
# We utilize the `pooch` package to fetch molecular dynamics (MD) simulation data from a Zenodo repository. This data includes both the topology (PSF) and trajectory (DCD) files of a minimized all-atom simulation of the Tau protein wild-type sequence.

# %%
# Create a pooch object with the base URL and compressed file handling
zenodo = pooch.create(
    path="./.data",  # Local storage location
    base_url="https://zenodo.org/records/14900596/files/",
    registry={
        "Zenodo_Rh_pCALVADOS.tar": None  # The compressed archive
    }
)

# First, fetch the compressed archive
tar_file = zenodo.fetch("Zenodo_Rh_pCALVADOS.tar")

# Extract the specific files from the archive with correct paths
with tarfile.open(tar_file) as tar:
    tar.extract("Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/topology_Tau_minimized_all_atoms_sequence_WT_renumerote.psf", path="./.data")
    tar.extract("Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/trajectory_Tau_minimized_all_atoms_sequence_WT.dcd", path="./.data")

# Update registry with correct paths
zenodo.registry.update({
    "Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/topology_Tau_minimized_all_atoms_sequence_WT_renumerote.psf": None,
    "Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/trajectory_Tau_minimized_all_atoms_sequence_WT.dcd": None
})

# Fetch the files from the extracted location
topology_file = zenodo.fetch("Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/topology_Tau_minimized_all_atoms_sequence_WT_renumerote.psf")
trajectory_file = zenodo.fetch("Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/trajectory_Tau_minimized_all_atoms_sequence_WT.dcd")

print(f"PSF file downloaded to: {topology_file}")
print(f"DCD file downloaded to: {trajectory_file}")
# Out:
# PSF file downloaded to: /home/etienne-reboul/projects/Menger_curvature_Daskified/menger_curvature/notebooks/.data/Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/topology_Tau_minimized_all_atoms_sequence_WT_renumerote.psf
# DCD file downloaded to: /home/etienne-reboul/projects/Menger_curvature_Daskified/menger_curvature/notebooks/.data/Zenodo_Rh_pCALVADOS/Trajectory_sequence_WT/all_atom_minimized_trajectory/trajectory_Tau_minimized_all_atoms_sequence_WT.dcd

# %% [markdown]
# ## Step 2- Benchmark Neq
# We will perform 3 replicas to benchmark the computation of the neq metric from PBxplore on both Tau protein and tubulin chain A molecular dynamics data.

# %%
def benchmark_pbxplore(trajectory_file, topology_file, n_replicas=3):
    """
    Benchmark PBxplore analysis performance.
    
    Parameters:
    -----------
    dcd_file : str
        Path to the DCD trajectory file
    psf_file : str
        Path to the PSF topology file
    n_replicas : int, optional
        Number of benchmark replicas to run (default=3)
        
    Returns:
    --------
    tuple
        (mean_time, std_time) in seconds
    """
    times = []
    
    for _ in range(n_replicas):
        start_time = time.perf_counter()
        
        # Original analysis code
        sequences = []
        for chain_name, chain in pbx.chains_from_trajectory(trajectory_file, topology_file):
            dihedrals = chain.get_phi_psi_angles()
            pb_seq = pbx.assign(dihedrals)
            sequences.append(pb_seq)

        count_matrix = pbx.analysis.count_matrix(sequences)
        neq_by_position = pbx.analysis.compute_neq(count_matrix)
        
        end_time = time.perf_counter()
        execution_time = end_time - start_time
        times.append(execution_time)

    mean_time = np.mean(times)
    std_time = np.std(times)
    
    return mean_time, std_time

# %%
files.TUBULIN_CHAIN_A_DCD
# Out:
# PosixPath('/home/etienne-reboul/projects/Menger_curvature_Daskified/menger_curvature/menger/data/test_data/tubulin_chain_a.dcd')

# %%
# benchmark on Tau protein MD
mean_time, std_time = benchmark_pbxplore(trajectory_file,topology_file , n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.2f} seconds")
# Out:
# Frame 1/20000.
# Frame 100/20000.
# Frame 200/20000.
# Frame 300/20000.
# Frame 400/20000.
# Frame 500/20000.
# Frame 600/20000.
# Frame 700/20000.
# Frame 800/20000.
# Frame 900/20000.
# Frame 1000/20000.
# Frame 1100/20000.
# Frame 1200/20000.
# Frame 1300/20000.
# Frame 1400/20000.
# Frame 1500/20000.
# Frame 1600/20000.
# Frame 1700/20000.
# Frame 1800/20000.
# Frame 1900/20000.
# Frame 2000/20000.
# Frame 2100/20000.
# Frame 2200/20000.
# Frame 2300/20000.
# Frame 2400/20000.
# Frame 2500/20000.
# Frame 2600/20000.
# Frame 2700/20000.
# Frame 2800/20000.
# Frame 2900/20000.
# Frame 3000/20000.
# Frame 3100/20000.
# Frame 3200/20000.
# Frame 3300/20000.
# Frame 3400/20000.
# Frame 3500/20000.
# Frame 3600/20000.
# Frame 3700/20000.
# Frame 3800/20000.
# Frame 3900/20000.
# Frame 4000/20000.
# Frame 4100/20000.
# Frame 4200/20000.
# Frame 4300/20000.
# Frame 4400/20000.
# Frame 4500/20000.
# Frame 4600/20000.
# Frame 4700/20000.
# Frame 4800/20000.
# Frame 4900/20000.
# Frame 5000/20000.
# Frame 5100/20000.
# Frame 5200/20000.
# Frame 5300/20000.
# Frame 5400/20000.
# Frame 5500/20000.
# Frame 5600/20000.
# Frame 5700/20000.
# Frame 5800/20000.
# Frame 5900/20000.
# Frame 6000/20000.
# Frame 6100/20000.
# Frame 6200/20000.
# Frame 6300/20000.
# Frame 6400/20000.
# Frame 6500/20000.
# Frame 6600/20000.
# Frame 6700/20000.
# Frame 6800/20000.
# Frame 6900/20000.
# Frame 7000/20000.
# Frame 7100/20000.
# Frame 7200/20000.
# Frame 7300/20000.
# Frame 7400/20000.
# Frame 7500/20000.
# Frame 7600/20000.
# Frame 7700/20000.
# Frame 7800/20000.
# Frame 7900/20000.
# Frame 8000/20000.
# Frame 8100/20000.
# Frame 8200/20000.
# Frame 8300/20000.
# Frame 8400/20000.
# Frame 8500/20000.
# Frame 8600/20000.
# Frame 8700/20000.
# Frame 8800/20000.
# Frame 8900/20000.
# Frame 9000/20000.
# Frame 9100/20000.
# Frame 9200/20000.
# Frame 9300/20000.
# Frame 9400/20000.
# Frame 9500/20000.
# Frame 9600/20000.
# Frame 9700/20000.
# Frame 9800/20000.
# Frame 9900/20000.
# Frame 10000/20000.
# Frame 10100/20000.
# Frame 10200/20000.
# Frame 10300/20000.
# Frame 10400/20000.
# Frame 10500/20000.
# Frame 10600/20000.
# Frame 10700/20000.
# Frame 10800/20000.
# Frame 10900/20000.
# Frame 11000/20000.
# Frame 11100/20000.
# Frame 11200/20000.
# Frame 11300/20000.
# Frame 11400/20000.
# Frame 11500/20000.
# Frame 11600/20000.
# Frame 11700/20000.
# Frame 11800/20000.
# Frame 11900/20000.
# Frame 12000/20000.
# Frame 12100/20000.
# Frame 12200/20000.
# Frame 12300/20000.
# Frame 12400/20000.
# Frame 12500/20000.
# Frame 12600/20000.
# Frame 12700/20000.
# Frame 12800/20000.
# Frame 12900/20000.
# Frame 13000/20000.
# Frame 13100/20000.
# Frame 13200/20000.
# Frame 13300/20000.
# Frame 13400/20000.
# Frame 13500/20000.
# Frame 13600/20000.
# Frame 13700/20000.
# Frame 13800/20000.
# Frame 13900/20000.
# Frame 14000/20000.
# Frame 14100/20000.
# Frame 14200/20000.
# Frame 14300/20000.
# Frame 14400/20000.
# Frame 14500/20000.
# Frame 14600/20000.
# Frame 14700/20000.
# Frame 14800/20000.
# Frame 14900/20000.
# Frame 15000/20000.
# Frame 15100/20000.
# Frame 15200/20000.
# Frame 15300/20000.
# Frame 15400/20000.
# Frame 15500/20000.
# Frame 15600/20000.
# Frame 15700/20000.
# Frame 15800/20000.
# Frame 15900/20000.
# Frame 16000/20000.
# Frame 16100/20000.
# Frame 16200/20000.
# Frame 16300/20000.
# Frame 16400/20000.
# Frame 16500/20000.
# Frame 16600/20000.
# Frame 16700/20000.
# Frame 16800/20000.
# Frame 16900/20000.
# Frame 17000/20000.
# Frame 17100/20000.
# Frame 17200/20000.
# Frame 17300/20000.
# Frame 17400/20000.
# Frame 17500/20000.
# Frame 17600/20000.
# Frame 17700/20000.
# Frame 17800/20000.
# Frame 17900/20000.
# Frame 18000/20000.
# Frame 18100/20000.
# Frame 18200/20000.
# Frame 18300/20000.
# Frame 18400/20000.
# Frame 18500/20000.
# Frame 18600/20000.
# Frame 18700/20000.
# Frame 18800/20000.
# Frame 18900/20000.
# Frame 19000/20000.
# Frame 19100/20000.
# Frame 19200/20000.
# Frame 19300/20000.
# Frame 19400/20000.
# Frame 19500/20000.
# Frame 19600/20000.
# Frame 19700/20000.
# Frame 19800/20000.
# Frame 19900/20000.
# Frame 20000/20000.
# Frame 20000/20000.
# Frame 1/20000.
# Frame 100/20000.
# Frame 200/20000.
# Frame 300/20000.
# Frame 400/20000.
# Frame 500/20000.
# Frame 600/20000.
# Frame 700/20000.
# Frame 800/20000.
# Frame 900/20000.
# Frame 1000/20000.
# Frame 1100/20000.
# Frame 1200/20000.
# Frame 1300/20000.
# Frame 1400/20000.
# Frame 1500/20000.
# Frame 1600/20000.
# Frame 1700/20000.
# Frame 1800/20000.
# Frame 1900/20000.
# Frame 2000/20000.
# Frame 2100/20000.
# Frame 2200/20000.
# Frame 2300/20000.
# Frame 2400/20000.
# Frame 2500/20000.
# Frame 2600/20000.
# Frame 2700/20000.
# Frame 2800/20000.
# Frame 2900/20000.
# Frame 3000/20000.
# Frame 3100/20000.
# Frame 3200/20000.
# Frame 3300/20000.
# Frame 3400/20000.
# Frame 3500/20000.
# Frame 3600/20000.
# Frame 3700/20000.
# Frame 3800/20000.
# Frame 3900/20000.
# Frame 4000/20000.
# Frame 4100/20000.
# Frame 4200/20000.
# Frame 4300/20000.
# Frame 4400/20000.
# Frame 4500/20000.
# Frame 4600/20000.
# Frame 4700/20000.
# Frame 4800/20000.
# Frame 4900/20000.
# Frame 5000/20000.
# Frame 5100/20000.
# Frame 5200/20000.
# Frame 5300/20000.
# Frame 5400/20000.
# Frame 5500/20000.
# Frame 5600/20000.
# Frame 5700/20000.
# Frame 5800/20000.
# Frame 5900/20000.
# Frame 6000/20000.
# Frame 6100/20000.
# Frame 6200/20000.
# Frame 6300/20000.
# Frame 6400/20000.
# Frame 6500/20000.
# Frame 6600/20000.
# Frame 6700/20000.
# Frame 6800/20000.
# Frame 6900/20000.
# Frame 7000/20000.
# Frame 7100/20000.
# Frame 7200/20000.
# Frame 7300/20000.
# Frame 7400/20000.
# Frame 7500/20000.
# Frame 7600/20000.
# Frame 7700/20000.
# Frame 7800/20000.
# Frame 7900/20000.
# Frame 8000/20000.
# Frame 8100/20000.
# Frame 8200/20000.
# Frame 8300/20000.
# Frame 8400/20000.
# Frame 8500/20000.
# Frame 8600/20000.
# Frame 8700/20000.
# Frame 8800/20000.
# Frame 8900/20000.
# Frame 9000/20000.
# Frame 9100/20000.
# Frame 9200/20000.
# Frame 9300/20000.
# Frame 9400/20000.
# Frame 9500/20000.
# Frame 9600/20000.
# Frame 9700/20000.
# Frame 9800/20000.
# Frame 9900/20000.
# Frame 10000/20000.
# Frame 10100/20000.
# Frame 10200/20000.
# Frame 10300/20000.
# Frame 10400/20000.
# Frame 10500/20000.
# Frame 10600/20000.
# Frame 10700/20000.
# Frame 10800/20000.
# Frame 10900/20000.
# Frame 11000/20000.
# Frame 11100/20000.
# Frame 11200/20000.
# Frame 11300/20000.
# Frame 11400/20000.
# Frame 11500/20000.
# Frame 11600/20000.
# Frame 11700/20000.
# Frame 11800/20000.
# Frame 11900/20000.
# Frame 12000/20000.
# Frame 12100/20000.
# Frame 12200/20000.
# Frame 12300/20000.
# Frame 12400/20000.
# Frame 12500/20000.
# Frame 12600/20000.
# Frame 12700/20000.
# Frame 12800/20000.
# Frame 12900/20000.
# Frame 13000/20000.
# Frame 13100/20000.
# Frame 13200/20000.
# Frame 13300/20000.
# Frame 13400/20000.
# Frame 13500/20000.
# Frame 13600/20000.
# Frame 13700/20000.
# Frame 13800/20000.
# Frame 13900/20000.
# Frame 14000/20000.
# Frame 14100/20000.
# Frame 14200/20000.
# Frame 14300/20000.
# Frame 14400/20000.
# Frame 14500/20000.
# Frame 14600/20000.
# Frame 14700/20000.
# Frame 14800/20000.
# Frame 14900/20000.
# Frame 15000/20000.
# Frame 15100/20000.
# Frame 15200/20000.
# Frame 15300/20000.
# Frame 15400/20000.
# Frame 15500/20000.
# Frame 15600/20000.
# Frame 15700/20000.
# Frame 15800/20000.
# Frame 15900/20000.
# Frame 16000/20000.
# Frame 16100/20000.
# Frame 16200/20000.
# Frame 16300/20000.
# Frame 16400/20000.
# Frame 16500/20000.
# Frame 16600/20000.
# Frame 16700/20000.
# Frame 16800/20000.
# Frame 16900/20000.
# Frame 17000/20000.
# Frame 17100/20000.
# Frame 17200/20000.
# Frame 17300/20000.
# Frame 17400/20000.
# Frame 17500/20000.
# Frame 17600/20000.
# Frame 17700/20000.
# Frame 17800/20000.
# Frame 17900/20000.
# Frame 18000/20000.
# Frame 18100/20000.
# Frame 18200/20000.
# Frame 18300/20000.
# Frame 18400/20000.
# Frame 18500/20000.
# Frame 18600/20000.
# Frame 18700/20000.
# Frame 18800/20000.
# Frame 18900/20000.
# Frame 19000/20000.
# Frame 19100/20000.
# Frame 19200/20000.
# Frame 19300/20000.
# Frame 19400/20000.
# Frame 19500/20000.
# Frame 19600/20000.
# Frame 19700/20000.
# Frame 19800/20000.
# Frame 19900/20000.
# Frame 20000/20000.
# Frame 20000/20000.
# Frame 1/20000.
# Frame 100/20000.
# Frame 200/20000.
# Frame 300/20000.
# Frame 400/20000.
# Frame 500/20000.
# Frame 600/20000.
# Frame 700/20000.
# Frame 800/20000.
# Frame 900/20000.
# Frame 1000/20000.
# Frame 1100/20000.
# Frame 1200/20000.
# Frame 1300/20000.
# Frame 1400/20000.
# Frame 1500/20000.
# Frame 1600/20000.
# Frame 1700/20000.
# Frame 1800/20000.
# Frame 1900/20000.
# Frame 2000/20000.
# Frame 2100/20000.
# Frame 2200/20000.
# Frame 2300/20000.
# Frame 2400/20000.
# Frame 2500/20000.
# Frame 2600/20000.
# Frame 2700/20000.
# Frame 2800/20000.
# Frame 2900/20000.
# Frame 3000/20000.
# Frame 3100/20000.
# Frame 3200/20000.
# Frame 3300/20000.
# Frame 3400/20000.
# Frame 3500/20000.
# Frame 3600/20000.
# Frame 3700/20000.
# Frame 3800/20000.
# Frame 3900/20000.
# Frame 4000/20000.
# Frame 4100/20000.
# Frame 4200/20000.
# Frame 4300/20000.
# Frame 4400/20000.
# Frame 4500/20000.
# Frame 4600/20000.
# Frame 4700/20000.
# Frame 4800/20000.
# Frame 4900/20000.
# Frame 5000/20000.
# Frame 5100/20000.
# Frame 5200/20000.
# Frame 5300/20000.
# Frame 5400/20000.
# Frame 5500/20000.
# Frame 5600/20000.
# Frame 5700/20000.
# Frame 5800/20000.
# Frame 5900/20000.
# Frame 6000/20000.
# Frame 6100/20000.
# Frame 6200/20000.
# Frame 6300/20000.
# Frame 6400/20000.
# Frame 6500/20000.
# Frame 6600/20000.
# Frame 6700/20000.
# Frame 6800/20000.
# Frame 6900/20000.
# Frame 7000/20000.
# Frame 7100/20000.
# Frame 7200/20000.
# Frame 7300/20000.
# Frame 7400/20000.
# Frame 7500/20000.
# Frame 7600/20000.
# Frame 7700/20000.
# Frame 7800/20000.
# Frame 7900/20000.
# Frame 8000/20000.
# Frame 8100/20000.
# Frame 8200/20000.
# Frame 8300/20000.
# Frame 8400/20000.
# Frame 8500/20000.
# Frame 8600/20000.
# Frame 8700/20000.
# Frame 8800/20000.
# Frame 8900/20000.
# Frame 9000/20000.
# Frame 9100/20000.
# Frame 9200/20000.
# Frame 9300/20000.
# Frame 9400/20000.
# Frame 9500/20000.
# Frame 9600/20000.
# Frame 9700/20000.
# Frame 9800/20000.
# Frame 9900/20000.
# Frame 10000/20000.
# Frame 10100/20000.
# Frame 10200/20000.
# Frame 10300/20000.
# Frame 10400/20000.
# Frame 10500/20000.
# Frame 10600/20000.
# Frame 10700/20000.
# Frame 10800/20000.
# Frame 10900/20000.
# Frame 11000/20000.
# Frame 11100/20000.
# Frame 11200/20000.
# Frame 11300/20000.
# Frame 11400/20000.
# Frame 11500/20000.
# Frame 11600/20000.
# Frame 11700/20000.
# Frame 11800/20000.
# Frame 11900/20000.
# Frame 12000/20000.
# Frame 12100/20000.
# Frame 12200/20000.
# Frame 12300/20000.
# Frame 12400/20000.
# Frame 12500/20000.
# Frame 12600/20000.
# Frame 12700/20000.
# Frame 12800/20000.
# Frame 12900/20000.
# Frame 13000/20000.
# Frame 13100/20000.
# Frame 13200/20000.
# Frame 13300/20000.
# Frame 13400/20000.
# Frame 13500/20000.
# Frame 13600/20000.
# Frame 13700/20000.
# Frame 13800/20000.
# Frame 13900/20000.
# Frame 14000/20000.
# Frame 14100/20000.
# Frame 14200/20000.
# Frame 14300/20000.
# Frame 14400/20000.
# Frame 14500/20000.
# Frame 14600/20000.
# Frame 14700/20000.
# Frame 14800/20000.
# Frame 14900/20000.
# Frame 15000/20000.
# Frame 15100/20000.
# Frame 15200/20000.
# Frame 15300/20000.
# Frame 15400/20000.
# Frame 15500/20000.
# Frame 15600/20000.
# Frame 15700/20000.
# Frame 15800/20000.
# Frame 15900/20000.
# Frame 16000/20000.
# Frame 16100/20000.
# Frame 16200/20000.
# Frame 16300/20000.
# Frame 16400/20000.
# Frame 16500/20000.
# Frame 16600/20000.
# Frame 16700/20000.
# Frame 16800/20000.
# Frame 16900/20000.
# Frame 17000/20000.
# Frame 17100/20000.
# Frame 17200/20000.
# Frame 17300/20000.
# Frame 17400/20000.
# Frame 17500/20000.
# Frame 17600/20000.
# Frame 17700/20000.
# Frame 17800/20000.
# Frame 17900/20000.
# Frame 18000/20000.
# Frame 18100/20000.
# Frame 18200/20000.
# Frame 18300/20000.
# Frame 18400/20000.
# Frame 18500/20000.
# Frame 18600/20000.
# Frame 18700/20000.
# Frame 18800/20000.
# Frame 18900/20000.
# Frame 19000/20000.
# Frame 19100/20000.
# Frame 19200/20000.
# Frame 19300/20000.
# Frame 19400/20000.
# Frame 19500/20000.
# Frame 19600/20000.
# Frame 19700/20000.
# Frame 19800/20000.
# Frame 19900/20000.
# Frame 20000/20000.
# Frame 20000/20000.
# Mean execution time: 218.48 ± 1.17 seconds

# %%
# Benchmark the analysis on the tubulin data
mean_time, std_time = benchmark_pbxplore(files.TUBULIN_CHAIN_A_DCD, files.TUBULIN_CHAIN_A_PDB, n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.2f} seconds")
# Out:
# Frame 1/1000.
# Frame 100/1000.
# Frame 200/1000.
# Frame 300/1000.
# Frame 400/1000.
# Frame 500/1000.
# Frame 600/1000.
# Frame 700/1000.
# Frame 800/1000.
# Frame 900/1000.
# Frame 1000/1000.
# Frame 1000/1000.
# Frame 1/1000.
# Frame 100/1000.
# Frame 200/1000.
# Frame 300/1000.
# Frame 400/1000.
# Frame 500/1000.
# Frame 600/1000.
# Frame 700/1000.
# Frame 800/1000.
# Frame 900/1000.
# Frame 1000/1000.
# Frame 1000/1000.
# Frame 1/1000.
# Frame 100/1000.
# Frame 200/1000.
# Frame 300/1000.
# Frame 400/1000.
# Frame 500/1000.
# Frame 600/1000.
# Frame 700/1000.
# Frame 800/1000.
# Frame 900/1000.
# Mean execution time: 10.54 ± 0.17 seconds
# Frame 1000/1000.
# Frame 1000/1000.

# %% [markdown]
# ## Step 3- Benchmark RMSF
# We will perform 3 replicas to benchmark the computation of the Root Mean Square Fluctuation (RMSF) from MDAnalysis implementation on both Tau protein and tubulin chain A molecular dynamics data.

# %%
def benchmark_rmsf(topology_file, trajectory_file, n_replicas=3):
    """
    Benchmark RMSF analysis performance using MDAnalysis.
    
    Parameters:
    -----------
    topology_file : str
        Path to the topology file (PSF/PDB)
    trajectory_file : str
        Path to the trajectory file (DCD)
    n_replicas : int, optional
        Number of benchmark replicas to run (default=3)
        
    Returns:
    --------
    tuple
        (mean_time, std_time) in seconds
    """
    times = []
    
    for _ in range(n_replicas):
        start_time = time.perf_counter()
        
        # Load the system
        u = mda.Universe(topology_file, trajectory_file)
        
        # Calculate average structure and align
        average = align.AverageStructure(u, u, select='protein and name CA',
                                       ref_frame=0).run()
        ref = average.results.universe
        aligner = align.AlignTraj(u, ref,
                                select='protein and name CA',
                                in_memory=True).run()
        
        # Calculate RMSF
        c_alphas = u.select_atoms('protein and name CA')
        R = rms.RMSF(c_alphas).run()
        
        end_time = time.perf_counter()
        execution_time = end_time - start_time
        times.append(execution_time)

    mean_time = np.mean(times)
    std_time = np.std(times)
    
    return mean_time, std_time

# %%
# Benchmark RMSF on Tau protein MD
mean_time, std_time = benchmark_rmsf(topology_file, trajectory_file, n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.2f} seconds")
# Out:
# Mean execution time: 22.96 ± 0.44 seconds

# %%
# Benchmark RMSF on Tubulin chain A MD
mean_time, std_time = benchmark_rmsf(files.TUBULIN_CHAIN_A_PDB, files.TUBULIN_CHAIN_A_DCD, n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.2f} seconds")
# Out:
# Mean execution time: 1.21 ± 0.02 seconds

# %% [markdown]
# ## Step 4- Benchmark Menger Curvature
# We will perform 3 replicas to benchmark the computation of Menger curvature on both Tau protein and tubulin chain A molecular dynamics data. The Menger curvature provides a geometric measure of the curvature through three consecutive points along the protein backbone.

# %%
def benchmark_menger(topology_file, trajectory_file, n_replicas=3):
    """
    Benchmark Menger curvature analysis performance.
    
    Parameters:
    -----------
    topology_file : str
        Path to the topology file (PSF/PDB)
    trajectory_file : str
        Path to the trajectory file (DCD)
    n_replicas : int, optional
        Number of benchmark replicas to run (default=3)
        
    Returns:
    --------
    tuple
        (mean_time, std_time) in seconds
    """
    times = []
    
    for _ in range(n_replicas):
        start_time = time.perf_counter()
        
        # Load the system
        u = mda.Universe(topology_file, trajectory_file)
        
        # Calculate Menger curvature
        menger_analyser = MengerCurvature(
            u,
            select="name CA",
            spacing=2
        )
        menger_analyser.run()
        
        end_time = time.perf_counter()
        execution_time = end_time - start_time
        times.append(execution_time)

    mean_time = np.mean(times)
    std_time = np.std(times)
    
    return mean_time, std_time

# %%
# Benchmark Menger curvature on Tau protein MD
mean_time, std_time = benchmark_menger(topology_file, trajectory_file, n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.2f} seconds")
# Out:
# Mean execution time: 4.54 ± 0.50 seconds

# %%
# Benchmark Menger curvature on Tubulin chain A MD
mean_time, std_time = benchmark_menger(files.TUBULIN_CHAIN_A_PDB, files.TUBULIN_CHAIN_A_DCD, n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.3f} seconds")
# Out:
# Mean execution time: 0.23 ± 0.003 seconds

# %%
def benchmark_menger_parallel(topology_file, trajectory_file, n_replicas=3, n_workers=4):
    """
    Benchmark parallel Menger curvature analysis performance.
    
    Parameters:
    -----------
    topology_file : str
        Path to the topology file (PSF/PDB)
    trajectory_file : str
        Path to the trajectory file (DCD)
    n_replicas : int, optional
        Number of benchmark replicas to run (default=3)
    n_workers : int, optional
        Number of parallel workers to use (default=4)
        
    Returns:
    --------
    tuple
        (mean_time, std_time) in seconds
    """
    times = []
    
    for _ in range(n_replicas):
        start_time = time.perf_counter()
        
        # Load the system
        u = mda.Universe(topology_file, trajectory_file)
        
        # Calculate Menger curvature using parallel processing
        menger_analyser = MengerCurvature(
            u,
            select="name CA",
            spacing=2,
            n_workers=n_workers
        )
        menger_analyser.run_parallel()
        
        end_time = time.perf_counter()
        execution_time = end_time - start_time
        times.append(execution_time)

    mean_time = np.mean(times)
    std_time = np.std(times)
    
    return mean_time, std_time

# %%
# Benchmark Menger curvature on Tau protein MD
mean_time, std_time = benchmark_menger_parallel(topology_file, trajectory_file, n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.2f} seconds")
# Out:
# Mean execution time: 2.84 ± 0.05 seconds

# %%
# Benchmark Menger curvature on Tau protein MD
mean_time, std_time = benchmark_menger_parallel(files.TUBULIN_CHAIN_A_PDB, files.TUBULIN_CHAIN_A_DCD, n_replicas=3)

print(f"Mean execution time: {mean_time:.2f} ± {std_time:.3f} seconds")
# Out:
# Mean execution time: 0.19 ± 0.009 seconds
